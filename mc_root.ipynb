// %%
TFile *root_sim = new TFile("/Users/tylern/Desktop/show/mc_today.root");
gStyle->SetOptStat(0);

// %%
auto recons = (TH2D *)root_sim->Get("W vs Q2/CosThetaVsPhi_channel");
auto thrown = (TH2D *)root_sim->Get("W vs Q2 MC/CosThetaVsPhi_mc");

// %%
auto canvas = new TCanvas("c1", "c1",1200,800);
thrown->Draw();
canvas->Draw();

// %%
auto canvas = new TCanvas("c1", "c1",1200,800);
recons->Draw();
canvas->Draw();
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

// %%
auto canvas = new TCanvas("c1", "c1",1200,800);
recons->Divide(thrown);
recons->Draw();
canvas->Draw();
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
